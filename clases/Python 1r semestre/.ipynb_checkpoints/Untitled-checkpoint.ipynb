# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("df1.csv", delimiter = ",", encoding = "unicode_escape")
df.head()
# Out:
#   ï»¿collision_index  collision_year collision_reference  vehicle_reference  \
# 0      2023010419171            2023           010419171                  1
# 1      2023010419183            2023           010419183                  2
# 2      2023010419183            2023           010419183                  3
# 3      2023010419189            2023           010419189                  1
# 4      2023010419191            2023           010419191                  2
#
#    casualty_reference  casualty_class  sex_of_casualty  age_of_casualty  \
# 0                   1               3                2               20
# 1                   1               1                1               25
# 2                   2               2                2               38
# 3                   1               1                1               50
# 4                   1               1                1               34
#
#    age_band_of_casualty  casualty_severity  pedestrian_location  \
# ...

# %%
df.tail()
# Out:
#       ï»¿collision_index  collision_year collision_reference  \
# 62669      2023991365442            2023           991365442
# 62670      2023991366101            2023           991366101
# 62671      2023991366235            2023           991366235
# 62672      2023991369054            2023           991369054
# 62673      2023991369155            2023           991369155
#
#        vehicle_reference  casualty_reference  casualty_class  sex_of_casualty  \
# 62669                  1                   1               1                1
# 62670                  1                   1               3                2
# 62671                  1                   1               3                2
# 62672                  2                   1               1                1
# 62673                  2                   1               1                1
#
#        age_of_casualty  age_band_of_casualty  casualty_severity  \
# ...

# %%
df.dtypes
# Out:
# ï»¿collision_index                    object
# collision_year                         int64
# collision_reference                   object
# vehicle_reference                      int64
# casualty_reference                     int64
# casualty_class                         int64
# sex_of_casualty                        int64
# age_of_casualty                        int64
# age_band_of_casualty                   int64
# casualty_severity                      int64
# pedestrian_location                    int64
# pedestrian_movement                    int64
# car_passenger                          int64
# bus_or_coach_passenger                 int64
# pedestrian_road_maintenance_worker     int64
# casualty_type                          int64
# casualty_home_area_type                int64
# casualty_imd_decile                    int64
# lsoa_of_casualty                      object
# dtype: object

# %%
df.count()
# Out:
# ï»¿collision_index                    62674
# collision_year                        62674
# collision_reference                   62674
# vehicle_reference                     62674
# casualty_reference                    62674
# casualty_class                        62674
# sex_of_casualty                       62674
# age_of_casualty                       62674
# age_band_of_casualty                  62674
# casualty_severity                     62674
# pedestrian_location                   62674
# pedestrian_movement                   62674
# car_passenger                         62674
# bus_or_coach_passenger                62674
# pedestrian_road_maintenance_worker    62674
# casualty_type                         62674
# casualty_home_area_type               62674
# casualty_imd_decile                   62674
# lsoa_of_casualty                      62674
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.count()
# Out:
# ï»¿collision_index                    62674
# collision_year                        62674
# collision_reference                   62674
# vehicle_reference                     62674
# casualty_reference                    62674
# casualty_class                        62674
# sex_of_casualty                       62674
# age_of_casualty                       62674
# age_band_of_casualty                  62674
# casualty_severity                     62674
# pedestrian_location                   62674
# pedestrian_movement                   62674
# car_passenger                         62674
# bus_or_coach_passenger                62674
# pedestrian_road_maintenance_worker    62674
# casualty_type                         62674
# casualty_home_area_type               62674
# casualty_imd_decile                   62674
# lsoa_of_casualty                      62674
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# ï»¿collision_index                    0
# collision_year                        0
# collision_reference                   0
# vehicle_reference                     0
# casualty_reference                    0
# casualty_class                        0
# sex_of_casualty                       0
# age_of_casualty                       0
# age_band_of_casualty                  0
# casualty_severity                     0
# pedestrian_location                   0
# pedestrian_movement                   0
# car_passenger                         0
# bus_or_coach_passenger                0
# pedestrian_road_maintenance_worker    0
# casualty_type                         0
# casualty_home_area_type               0
# casualty_imd_decile                   0
# lsoa_of_casualty                      0
# dtype: int64

# %%
import sqlite3 as sql

# %%
conn = sql.connect("tarea.db")

# %%
df.to_sql("accidentes_vehiculares", conn, if_exists = "replace")
# Out:
# 62674

# %%
leer_df = pd.read_sql("select * from accidentes_vehiculares", conn)
leer_df
# Out:
#        index ï»¿collision_index  collision_year collision_reference  \
# 0          0      2023010419171            2023           010419171
# 1          1      2023010419183            2023           010419183
# 2          2      2023010419183            2023           010419183
# 3          3      2023010419189            2023           010419189
# 4          4      2023010419191            2023           010419191
# ...      ...                ...             ...                 ...
# 62669  62669      2023991365442            2023           991365442
# 62670  62670      2023991366101            2023           991366101
# 62671  62671      2023991366235            2023           991366235
# 62672  62672      2023991369054            2023           991369054
# 62673  62673      2023991369155            2023           991369155
#
#        vehicle_reference  casualty_reference  casualty_class  sex_of_casualty  \
# ...

# %%
leer_df = pd.read_sql("select * from accidentes_vehiculares", conn).drop(columns=["index"])
leer_df
# Out:
#       ï»¿collision_index  collision_year collision_reference  \
# 0          2023010419171            2023           010419171
# 1          2023010419183            2023           010419183
# 2          2023010419183            2023           010419183
# 3          2023010419189            2023           010419189
# 4          2023010419191            2023           010419191
# ...                  ...             ...                 ...
# 62669      2023991365442            2023           991365442
# 62670      2023991366101            2023           991366101
# 62671      2023991366235            2023           991366235
# 62672      2023991369054            2023           991369054
# 62673      2023991369155            2023           991369155
#
#        vehicle_reference  casualty_reference  casualty_class  sex_of_casualty  \
# 0                      1                   1               3                2
# ...

# %%
comparar = df == leer_df
comparar
# Out:
#        ï»¿collision_index  collision_year  collision_reference  \
# 0                    True            True                 True
# 1                    True            True                 True
# 2                    True            True                 True
# 3                    True            True                 True
# 4                    True            True                 True
# ...                   ...             ...                  ...
# 62669                True            True                 True
# 62670                True            True                 True
# 62671                True            True                 True
# 62672                True            True                 True
# 62673                True            True                 True
#
#        vehicle_reference  casualty_reference  casualty_class  sex_of_casualty  \
# 0                   True                True            True             True
# ...

# %%
comparar.describe()
# Out:
#        ï»¿collision_index collision_year collision_reference  \
# count               62674          62674               62674
# unique                  1              1                   1
# top                  True           True                True
# freq                62674          62674               62674
#
#        vehicle_reference casualty_reference casualty_class sex_of_casualty  \
# count              62674              62674          62674           62674
# unique                 1                  1              1               1
# top                 True               True           True            True
# freq               62674              62674          62674           62674
#
#        age_of_casualty age_band_of_casualty casualty_severity  \
# count            62674                62674             62674
# unique               1                    1                 1
# top               True                 True              True
# ...

# %%
sns.catplot(x = "sex_of_casualty", y= "age_of_casualty", hue= "casualty_class", data = leer_df);
# Out:
# C:\Users\claud\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\claud\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(x ="age_of_casualty", data = leer_df)
# Out:
# <Axes: xlabel='age_of_casualty'>

# %%
sns.barplot(x=leer_df["sex_of_casualty"], y= leer_df["age_of_casualty"])
# Out:
# <Axes: xlabel='sex_of_casualty', ylabel='age_of_casualty'>

# %%
sns.histplot(x = "age_of_casualty", data = leer_df)
# Out:
# C:\Users\claud\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age_of_casualty', ylabel='Count'>
